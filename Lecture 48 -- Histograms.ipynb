# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1) # defaults to 10 bins
# Out:
# (array([  3.,   4.,  13.,  13.,  18.,  21.,  11.,   9.,   2.,   6.]),
#  array([-2.29971803, -1.84693772, -1.39415741, -0.9413771 , -0.4885968 ,
#         -0.03581649,  0.41696382,  0.86974413,  1.32252444,  1.77530475,
#          2.22808506]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color='indianred')
# Out:
# (array([  4.,   5.,   9.,  13.,  13.,  13.,  15.,   4.,   2.,   2.]),
#  array([-2.35262362, -1.81975489, -1.28688616, -0.75401743, -0.2211487 ,
#          0.31172002,  0.84458875,  1.37745748,  1.91032621,  2.44319494,
#          2.97606367]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='indianred',alpha=.5,bins=20)
plt.hist(dataset2,normed=True,alpha=.5,bins=20)
# Out:
# (array([ 0.14074761,  0.04691587,  0.        ,  0.23457935,  0.18766348,
#          0.23457935,  0.37532696,  0.23457935,  0.32841109,  0.28149522,
#          0.32841109,  0.28149522,  0.23457935,  0.4691587 ,  0.14074761,
#          0.04691587,  0.09383174,  0.        ,  0.04691587,  0.04691587]),
#  array([-2.35262362, -2.08618925, -1.81975489, -1.55332053, -1.28688616,
#         -1.0204518 , -0.75401743, -0.48758307, -0.2211487 ,  0.04528566,
#          0.31172002,  0.57815439,  0.84458875,  1.11102312,  1.37745748,
#          1.64389184,  1.91032621,  2.17676057,  2.44319494,  2.7096293 ,
#          2.97606367]),
#  <a list of 20 Patch objects>)

# %%
# Now with seaborn

data1 = randn(1000)
data2 = randn(1000)

# joint plot

sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')
